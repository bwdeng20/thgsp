# %% [markdown]
# # 1. BSGDA Sampling

# %%
import torch

from thgsp import Graph, loadmat
from thgsp.sampling.bsgda import bsgda, recon_bsgda
from thgsp.utils import mse, snr


def snr_and_mse(x, target):
    s, m = snr(x, target), mse(x, target)
    print(f"SNR: {s:.4f} | MSE: {m:.4e}")
    return s, m


dv = torch.device("cpu")
dt = torch.float

data = loadmat("bsgda.mat")
S = data["S"].ravel().astype(int) - 1

bw = data["bw"].item()
epsilon = data["epsilon"].item()
mu = data["mu"].item()
M = len(S)

f = torch.as_tensor(data["f"]).to(dt).to(dv)
y = torch.as_tensor(data["f_or"]).to(dt).to(dv)
L = Graph(data["L"]).to(dv, dt)
g = Graph(data["A"])
N = g.n_node

S2, _ = bsgda(L, M, mu, epsilon, 12, boost=False)
S1, _ = bsgda(L, M, mu, epsilon, 12)

print("MATLAB:       ", S)
print("Thgsp[boost]: ", S1)
print("Thgsp[nonbs]: ", S2)

f_hat = recon_bsgda(y[S], S, L, mu)
f_hat1 = recon_bsgda(y[S1], S1, L, mu)
f_hat2 = recon_bsgda(y[S1], S1, L, mu)
_, _ = snr_and_mse(f_hat, f)
_, _ = snr_and_mse(f_hat1, f)
_, _ = snr_and_mse(f_hat2, f)
# Out:
# /home/dengbw/anaconda3/envs/gsp/lib/python3.11/site-packages/scipy/io/matlab/_mio.py:235: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Considerscipy.io.matlab.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)
# MATLAB:        [ 0  1  2  3 13]
# Thgsp[boost]:  [12, 8, 13, 15, 18]
# Thgsp[nonbs]:  [12, 8, 13, 15, 18]
# SNR: 2.7528 | MSE: 5.3097e-01
# SNR: 2.1485 | MSE: 6.1026e-01
# SNR: 2.1485 | MSE: 6.1026e-01

# %% [markdown]
# # 2. ESS Sampling

# %%
import torch

from thgsp import Graph, loadmat
from thgsp.sampling import ess, recon_ess
from thgsp.utils import mse, snr


def snr_and_mse(x, target):
    s, m = snr(x, target), mse(x, target)
    print(f"SNR: {s:.4f} | MSE: {m:.4e}")
    return s, m


dv = torch.device("cpu")
dt = torch.float

data = loadmat("ess-comm.mat")
S = data["S"].ravel().astype(int) - 1

bw = data["bw"][0, 0].astype(int)
order = data["K"].astype(int)[0, 0]
print(order)

graph = Graph(data["A"]).to(dv).to(dt)
f = torch.as_tensor(data["f"]).to(dt).to(dv)
y = torch.as_tensor(data["f_or"]).to(dt).to(dv)
L = graph.L("comb")
U = graph.U("comb")

M = len(S)
S1 = ess(L, M, k=order // 2)
print(S)
print(S1)

f_hat1 = recon_ess(y[S], S, U, bw)
f_hat2 = recon_ess(y[S1], S1, U, bw)

s, m = snr_and_mse(f_hat1, f.to(dv))
_, _ = snr_and_mse(f_hat2, f.to(dv))
# Out:
# 4
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [  64.27013735 1318.71720258]
# not reaching the requested tolerance 7.450580596923828e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [113.23657167 872.00932225]
# not reaching the requested tolerance 7.4356794357299805e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [179.7252843  799.17889404]
# not reaching the requested tolerance 7.420778274536133e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [208.07884241 944.50608772]
# not reaching the requested tolerance 7.405877113342285e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [239.72372688 993.11977905]
# not reaching the requested tolerance 7.3909759521484375e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 256.30084756 1439.62246683]
# not reaching the requested tolerance 7.37607479095459e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [283.8541928  936.70570204]
# not reaching the requested tolerance 7.361173629760742e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [278.1320332  967.75657122]
# not reaching the requested tolerance 7.3462724685668945e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [385.61771116 624.29377684]
# not reaching the requested tolerance 7.331371307373047e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [469.8994271 619.7911024]
# not reaching the requested tolerance 7.316470146179199e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 527.6309836  1358.10346045]
# not reaching the requested tolerance 7.3015689849853516e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [475.77685848 975.06768464]
# not reaching the requested tolerance 7.286667823791504e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 584.63109502 1100.65842043]
# not reaching the requested tolerance 7.271766662597656e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 456.28014917 1225.06577509]
# not reaching the requested tolerance 7.256865501403809e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 604.4391288  1077.33967759]
# not reaching the requested tolerance 7.241964340209961e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [934.19206146 939.59376332]
# not reaching the requested tolerance 7.227063179016113e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [894.72865495 826.73479259]
# not reaching the requested tolerance 7.212162017822266e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 764.33874699 1056.75841842]
# not reaching the requested tolerance 7.197260856628418e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 522.10886046 1306.96863772]
# not reaching the requested tolerance 7.18235969543457e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [585.01527644 971.37445813]
# not reaching the requested tolerance 7.167458534240723e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 988.63515128 1092.97780103]
# not reaching the requested tolerance 7.152557373046875e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 900.33588126 1468.24405932]
# not reaching the requested tolerance 7.137656211853027e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 953.65436497 1808.14539396]
# not reaching the requested tolerance 7.12275505065918e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 919.94986906 1236.0614685 ]
# not reaching the requested tolerance 7.107853889465332e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [964.78935011 736.75087277]
# not reaching the requested tolerance 7.092952728271484e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1210.44173107 1052.22866425]
# not reaching the requested tolerance 7.078051567077637e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 887.60092323 1703.47338363]
# not reaching the requested tolerance 7.063150405883789e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 698.3636783  1453.86269086]
# not reaching the requested tolerance 7.048249244689941e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1345.48678339 2008.65730673]
# not reaching the requested tolerance 7.033348083496094e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 725.46208428 1288.69652557]
# not reaching the requested tolerance 7.018446922302246e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 954.45545282 1764.34231178]
# not reaching the requested tolerance 7.0035457611083984e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [994.40346377 922.45813156]
# not reaching the requested tolerance 6.988644599914551e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 821.07592322 1928.7571893 ]
# not reaching the requested tolerance 6.973743438720703e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1110.1203037  1864.88883407]
# not reaching the requested tolerance 6.9588422775268555e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1384.43910999 1932.17192482]
# not reaching the requested tolerance 6.943941116333008e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1219.05423456 1114.65853571]
# not reaching the requested tolerance 6.92903995513916e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1151.68036545 1712.07506878]
# not reaching the requested tolerance 6.9141387939453125e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 821.93093768 1617.12762688]
# not reaching the requested tolerance 6.899237632751465e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 853.28630347 1845.02998581]
# not reaching the requested tolerance 6.884336471557617e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 961.39582131 1236.19622863]
# not reaching the requested tolerance 6.8694353103637695e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1365.92861081 1768.40615305]
# not reaching the requested tolerance 6.854534149169922e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [844.40923238 754.10984873]
# not reaching the requested tolerance 6.839632987976074e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1154.85333009  902.39938254]
# not reaching the requested tolerance 6.8247318267822266e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1089.0813443  2638.05443236]
# not reaching the requested tolerance 6.809830665588379e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1187.81371878 2420.85353755]
# not reaching the requested tolerance 6.794929504394531e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 955.89161109 2030.73328992]
# not reaching the requested tolerance 6.780028343200684e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1081.68812785 1673.85836208]
# not reaching the requested tolerance 6.765127182006836e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1064.31742481 2405.51393836]
# not reaching the requested tolerance 6.750226020812988e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1750.90757781 1041.09189709]
# not reaching the requested tolerance 6.735324859619141e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1922.96092527 1599.53403779]
# not reaching the requested tolerance 6.720423698425293e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1679.2467722  1646.66559157]
# not reaching the requested tolerance 6.705522537231445e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 956.62262277 1748.43948369]
# not reaching the requested tolerance 6.690621376037598e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1002.48752957 1178.59582198]
# not reaching the requested tolerance 6.67572021484375e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1211.89375356 1302.06676472]
# not reaching the requested tolerance 6.660819053649902e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1718.79843114 1577.05481595]
# not reaching the requested tolerance 6.645917892456055e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1426.02779821  972.12655846]
# not reaching the requested tolerance 6.631016731262207e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1648.27298129 1053.43280313]
# not reaching the requested tolerance 6.616115570068359e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 631.61720631 1676.74398993]
# not reaching the requested tolerance 6.601214408874512e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1094.23888449 2046.65105783]
# not reaching the requested tolerance 6.586313247680664e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 895.74176    1362.33707303]
# not reaching the requested tolerance 6.571412086486816e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1309.24358809 1407.00118949]
# not reaching the requested tolerance 6.556510925292969e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1754.91282517 1247.27732193]
# not reaching the requested tolerance 6.541609764099121e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1158.82687234 1193.05303049]
# not reaching the requested tolerance 6.5267086029052734e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1103.57410604 1019.33825007]
# not reaching the requested tolerance 6.511807441711426e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1349.12378051 1668.91134339]
# not reaching the requested tolerance 6.496906280517578e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1029.69553668 1692.31816549]
# not reaching the requested tolerance 6.4820051193237305e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 596.40092484 2468.44115219]
# not reaching the requested tolerance 6.467103958129883e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1433.63929854 2079.15653246]
# not reaching the requested tolerance 6.452202796936035e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1648.3330152   944.88387963]
# not reaching the requested tolerance 6.4373016357421875e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1043.23033799 1905.3613307 ]
# not reaching the requested tolerance 6.42240047454834e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 903.70168606 1761.33835981]
# not reaching the requested tolerance 6.407499313354492e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1263.25751985 1126.63512969]
# not reaching the requested tolerance 6.3925981521606445e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 814.2635117  1134.55287936]
# not reaching the requested tolerance 6.377696990966797e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [717.10038979 822.51437999]
# not reaching the requested tolerance 6.362795829772949e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 765.25883548 2708.34484766]
# not reaching the requested tolerance 6.3478946685791016e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 865.86982802 1326.18319549]
# not reaching the requested tolerance 6.332993507385254e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1119.97477902 1482.61426569]
# not reaching the requested tolerance 6.318092346191406e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 963.013268   1347.87766736]
# not reaching the requested tolerance 6.303191184997559e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1022.23519813  984.48707664]
# not reaching the requested tolerance 6.288290023803711e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1304.11072871 1035.46194472]
# not reaching the requested tolerance 6.273388862609863e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1305.47399883 1086.56277127]
# not reaching the requested tolerance 6.258487701416016e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 974.96813251 1315.73133052]
# not reaching the requested tolerance 6.243586540222168e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1283.28700345 2065.29744569]
# not reaching the requested tolerance 6.22868537902832e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1676.23644621 2090.30703077]
# not reaching the requested tolerance 6.213784217834473e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [2178.29712    1461.89064975]
# not reaching the requested tolerance 6.198883056640625e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1242.90840535 2284.3552066 ]
# not reaching the requested tolerance 6.183981895446777e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1639.83823526  731.81502189]
# not reaching the requested tolerance 6.16908073425293e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1176.20488009  463.19385011]
# not reaching the requested tolerance 6.154179573059082e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 728.22439848 1760.41774163]
# not reaching the requested tolerance 6.139278411865234e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 541.24222129 1384.78106143]
# not reaching the requested tolerance 6.124377250671387e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [459.77266395 781.25108851]
# not reaching the requested tolerance 6.109476089477539e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 985.94910907 1949.1245077 ]
# not reaching the requested tolerance 6.094574928283691e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1052.04550163 2163.23194848]
# not reaching the requested tolerance 6.079673767089844e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1301.52566255 1680.99898211]
# not reaching the requested tolerance 6.064772605895996e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1305.50000291 1175.25129033]
# not reaching the requested tolerance 6.0498714447021484e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1009.61230998 1867.7382868 ]
# not reaching the requested tolerance 6.034970283508301e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [ 835.60411266 2010.07338871]
# not reaching the requested tolerance 6.020069122314453e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1833.7342409 1499.2324271]
# not reaching the requested tolerance 6.0051679611206055e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1212.72392319 2056.74441497]
# not reaching the requested tolerance 5.990266799926758e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)
# [332  22 414 116 210 390 495 461 351 147 479 171 102 182  66 344 149 243
#  323  84  18 409 465 338 426 491 205 172 419 397 155 322  21 175 448 490
#  342  60 410 471 104 242 314 399  15 134 109 126 310 454  74 462 416 234
#  494 196 377 296 415 183   7  69 315 160 440 387 433 485  13 349 396 469
#   88 151 253 115 197 327 353 404 487  33 302 165 309  12 439 473 411 187
#   44 341 133 468  30  37 380 121 489 405]
# [351, 66, 383, 116, 495, 160, 323, 15, 404, 479, 409, 196, 171, 353, 302, 440, 149, 53, 205, 243, 114, 423, 465, 3, 349, 386, 491, 172, 332, 259, 155, 314, 12, 396, 461, 415, 322, 104, 494, 471, 242, 377, 69, 126, 487, 426, 13, 342, 296, 165, 134, 109, 462, 411, 7, 457, 298, 267, 485, 88, 416, 214, 147, 60, 18, 315, 87, 387, 234, 183, 388, 414, 463, 210, 448, 327, 151, 371, 344, 310, 22, 380, 37, 490, 410, 454, 84, 432, 21, 341, 133, 289, 33, 473, 30, 489, 372, 284, 318, 121]
# SNR: 1.2057 | MSE: 7.5758e-01
# SNR: 1.1673 | MSE: 7.6431e-01
# /home/dengbw/projects/thgsp/thgsp/sampling/ess.py:53: UserWarning: Exited postprocessing with accuracies
# [1049.66177764 1001.67079357]
# not reaching the requested tolerance 5.97536563873291e-06.
#   sigma, psi = xsplin.lobpcg(reduced, X=guess, largest=False, maxiter=100)

# %% [markdown]
# # 3. RSBS Sampling

# %%
import torch
from torch_sparse import SparseTensor

from thgsp import loadmat
from thgsp.sampling.rsbs import recon_rsbs
from thgsp.utils import mse, snr


def snr_and_mse(x, target):
    s, m = snr(x, target), mse(x, target)
    print(f"SNR: {s:.4f} | MSE: {m:.4e}")
    return s, m


num_sig = 10  # repeat the signal for num_sig times


# Load Data captured from one trial of official code
# http://grsamplingbox.gforge.inria.fr.
# with the official code, the reconstruction SNR is about 30 dB, which is consistent
# with `rsbs` reconstruction in thgsp.


data = loadmat("rsbs.mat")
coh1 = data["weight"].ravel()  # distribution of nodes being sampled
S1 = data["ind_obs"].ravel().astype(int) - 1  # sampling node set
mu1 = data["mu"].item()  # the factor of regularization term
f = torch.as_tensor(data["x"])  # the original bandlimited signal
y = torch.as_tensor(data["ynoise_init"]).repeat(1, num_sig)  # the contaminated signal

L1 = SparseTensor.from_scipy(data["L"])  # the combinatorial laplacian used

f_hat = recon_rsbs(y, S=S1, L=L1, cum_coh=coh1, mu=mu1, reg_order=1)
s, m = snr_and_mse(f_hat.view(-1, num_sig), f)
# Out:
# SNR: 31.5076 | MSE: 7.0670e-07
